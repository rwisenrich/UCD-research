# %% [markdown]
# # UCD — SU(2) Quantum-Link Plaquette
#
# Public Google Colab runner for the UCD reproducibility repository.

# %%
# !rm -rf /content/UCD-research
# !git clone -q https://github.com/rwisenrich/UCD-research.git /content/UCD-research
# %cd /content/UCD-research
# !python -m pip -q install -r requirements.txt

# %%
# !python scripts/build_su2_qlm_plaquette.py
